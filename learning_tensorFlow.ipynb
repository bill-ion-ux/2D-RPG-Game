# %% [markdown]
# <a href="https://colab.research.google.com/github/bill-ion-ux/2D-RPG-Game/blob/main/learning_tensorFlow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**0. Import** **data**

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('Churn.csv')
df.head()
# Out:
#   Customer ID  Gender  Senior Citizen Partner Dependents  tenure  \
# 0  7590-VHVEA  Female               0     Yes         No       1
# 1  7590-VHVEG  Female               0     Yes         No       1
# 2  5575-GNVDE    Male               0      No         No      34
# 3  3668-QPYBK    Male               0      No         No       2
# 4  7795-CFOCW    Male               0      No         No      45
#
#   Phone Service    Multiple Lines Internet Service Online Security  ...  \
# 0            No  No phone service              DSL              No  ...
# 1            No  No phone service              DSL              No  ...
# 2           Yes                No              DSL             Yes  ...
# 3           Yes                No              DSL             Yes  ...
# 4            No  No phone service              DSL             Yes  ...
#
#   Device Protection Tech Support Streaming TV Streaming Movies  \
# 0                No           No           No               No
# ...

# %%
df['Total Charges'] = pd.to_numeric(df['Total Charges'], errors='coerce')

# %%
X = pd.get_dummies(df.drop(['Churn','Customer ID' ], axis=1)) #drop churn and customer ID column and convert categorical value to 1 and 0
y = df['Churn'].apply(lambda x: 1 if x == 'Yes' else 0) # store the targeted column(churn column) in 1 and 0

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
X_train.head()
# Out:
#       Senior Citizen  tenure  Monthly Charges  Total Charges  Gender_Female  \
# 6325               0       9            75.85         647.50           True
# 2319               0      71           100.50        7030.65           True
# 2585               0      58            65.25        3791.60           True
# 3867               0      19            25.60         485.90           True
# 6175               0       4            29.65         118.50          False
#
#       Gender_Male  Partner_No  Partner_Yes  Dependents_No  Dependents_Yes  \
# 6325        False       False         True          False            True
# 2319        False       False         True          False            True
# 2585        False       False         True           True           False
# 3867        False       False         True          False            True
# 6175         True        True        False           True           False
#
# ...

# %%
y_train.head()
# Out:
# 4091    0
# 1269    1
# 3062    1
# 5807    1
# 2390    0
# Name: Churn, dtype: int64

# %% [markdown]
# #**1. import dependencies**

# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense
from sklearn.metrics import accuracy_score

# %% [markdown]
# #**2.Build and Compile model**

# %%
model = Sequential()

# %%
model.add(Dense(units=32, activation='relu', input_dim=len(X_train.columns)))
model.add(Dense(units= 64, activation='relu'))
model.add(Dense(units=1, activation='sigmoid'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(loss='binary_crossentropy', optimizer='sgd', metrics=['accuracy'])

# %% [markdown]
# #**3. Fit, Predict and Evaluate**

# %%
model.fit(X_train, y_train, epochs=200, batch_size=32)
# Out:
# Epoch 1/200
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7199 - loss: nan
# Epoch 2/200
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7492 - loss: nan
# Epoch 3/200
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7366 - loss: nan
# Epoch 4/200
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7297 - loss: nan
# Epoch 5/200
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7321 - loss: nan
# Epoch 6/200
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7391 - loss: nan
# Epoch 7/200
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7377 - loss: nan
# Epoch 8/200
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7372 - loss: nan
# Epoch 9/200
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7404 - loss: nan
# Epoch 10/200
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7407 - loss: nan
# Epoch 11/200
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7483 - loss: nan
# Epoch 12/200
# ...

# %%
y_hat = model.predict(X_test)
y_hat = [0 if val < 0.5 else 1 for val in y_hat]
# Out:
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
accuracy_score(y_test, y_hat)
# Out:
# 0.2739531582682754
